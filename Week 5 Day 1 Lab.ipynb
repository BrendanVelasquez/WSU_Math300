# %% [markdown]
# # Week 5 Day 1 Lab

# %% [markdown]
# ### Problem 1
# Write your own function performs vectors addition on lists instead of arrays.

# %%
import numpy as np
import matplotlib.pyplot as plt

def vector_add(list1,list2):
    answer = []
    for i in range(len(list1)):
        answer.append(list1[i]+list2[i])
    return answer

x = [1,2,3,4]
y = [5,6,7,8]

vector_add(x,y)
# Out:
# [6, 8, 10, 12]

# %% [markdown]
# ### Problem 2
# Create two $3\times 2$ matrices, A and B. Compute:
# 1. A+B
# 2. AB

# %%
A = np.array([[1,2],[3,4],[5,6]])
B = np.array([[2,1],[0,3],[4,5]])

print("A + B")
print(A + B)

#for this problem AB is not possible because A is 3 by 2 and B is also 3 by 2
#because for matrix multiplication, the number of columns of A has to equal the number of rows of B
# Out:
# A + B
# [[ 3  3]
#  [ 3  7]
#  [ 9 11]]

# %% [markdown]
# ### Problem 3
# Make a 2 by 2 invertible matrix, A.
# 1. Compute its eigenvectors and plot them using matplotlib
# 2. Compute A times the eigenvectors and plot them on the same plot.
# 3. What do you notice?

# %%
A = np.array([[2, 1],[1, 2]])

print("determinant")
print(np.linalg.det(A))
eigenvalues,eigenvectors = np.linalg.eig(A)

print("eigenvalues")
print(eigenvalues)
print("eigenvectors")
print(eigenvectors)

v1 = eigenvectors[:, 0]
v2 = eigenvectors[:, 1]
Av1 = A @ v1
Av2 = A @ v2

plt.figure(figsize=(6,6))

plt.quiver(0,0,v1[0], v1[1],angles="xy",scale_units="xy", scale=1, label="v1")
plt.quiver(0,0,v2[0], v2[1],angles="xy",scale_units="xy", scale=1, label="v2")
plt.quiver(0,0,Av1[0], Av1[1],angles="xy",scale_units="xy", scale=1, label="A v1")
plt.quiver(0,0,Av2[0], Av2[1],angles="xy",scale_units="xy", scale=1, label="A v2")

plt.xlim(-4,4)
plt.ylim(-4,4)
plt.axhline(0)
plt.axvline(0)

plt.xlabel("x")
plt.ylabel("y")
plt.title("Eigenvectors and A times Eigenvectors")
plt.legend()
plt.grid()
plt.show()

# A times the eigenvectors stays in the same direction as the original eigenvectors, they just get stretched by the eigenvalues
# Out:
# determinant
# 2.9999999999999996
# eigenvalues
# [3. 1.]
# eigenvectors
# [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %% [markdown]
# ### Problem 4
# Write your own function that creates a random 3 by 3 matrix using `np.random` for the entries.

# %%
def random_matrix():
    matrix = np.random.randint(0, 10, size=(3, 3))
    return matrix
random_matrix()
# Out:
# array([[9, 4, 7],
#        [1, 2, 4],
#        [3, 8, 0]])
