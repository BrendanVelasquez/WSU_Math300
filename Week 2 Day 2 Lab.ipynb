# %% [markdown]
# # Week 2 Day Lab

# %% [markdown]
# ### Problem 1: Installing NumPy
#
# If not already installed, install the numpy library using `!pip install numpy`. After installing, import numpy with variable name `np`.

# %%
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: numpy in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (1.26.4)

# %%
import numpy as np

# %% [markdown]
# ### Problem 2: Installing other libraries
# We will use other libraries throughout this semester as well. Here are a couple:
#
#     - matplotlib
#     - networkx
#     - pandas
#     - geopandas
# Try importing these libraries. If they are not installed, use `pip install` to install them for future use.

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: matplotlib in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install networkx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: networkx in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (3.5)

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: pandas in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: geopandas in ./.local/lib/python3.12/site-packages (1.1.4)
# Requirement already satisfied: numpy>=1.24 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in ./.local/lib/python3.12/site-packages (from geopandas) (0.13.0)
# Requirement already satisfied: packaging in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from geopandas) (2.3.3)
# Requirement already satisfied: pyproj>=3.5.0 in ./.local/lib/python3.12/site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in ./.local/lib/python3.12/site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from pyogrio>=0.7.2->geopandas) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)

# %%
#checking the libraries import correctly
import matplotlib
import networkx
import pandas
import geopandas

# %% [markdown]
# ### Problem 3
#
# Given
#
# ```python
# a = np.array([2, 4, 6, 8])
# ```
#
# compute each of the following:
#
# 1. a + 3
# 2. 2 * a
# 3. a**2
# 4. a - 1
#
# Do not use a `for` loop.

# %%
a = np.array([2, 4, 6, 8])
print(a+3)
print(2*a)
print(a**2)
print(a-1)
# Out:
# [ 5  7  9 11]
# [ 4  8 12 16]
# [ 4 16 36 64]
# [1 3 5 7]

# %% [markdown]
# ### Problem 4
#
# The derivative of a function \(f(x)\) at a point \(x\) is defined as the limit
#
# $
# f'(x)=\lim_{h\to0}\frac{f(x+h)-f(x)}{h}
# $
#
# provided the limit exists.
#
# Define a function $g(h)$ that computes the quotient above for a given function $f$ near a point $x$. Then, vectorize $g$.
#
#
# Using `np.linspace()`, let $f(x)=sin(x)$ and compute $g$ at $10^{-1}, 10^{-2}, 10^{-3}, 10^{-4}$. This will be an estimate for the derivative of $f$. Compare to the actual derivative.

# %%
import math

# %%
x = np.pi # some point x

def g(h):                  
    return (f(x+h)-f(x))/h  # quotient for derivative

G = np.vectorize(g)   # vectorize g
def f(x):
    return math.sin(x) # f of choice

h = np.linspace(-1, -4, 4)   # -1, -2, -3, -4
h = 10**h                   # 10^-1, 10^-2, 10^-3, 10^-4

print(G(h))                 # evalutate the vectorized version of g at h values
print(math.cos(np.pi))      # actual derivative
# Out:
# [-0.99833417 -0.99998333 -0.99999983 -1.        ]
# -1.0

# %% [markdown]
# ###  Problem 5
# Let
#
# $
# A=
# \begin{bmatrix}
# 2 & 1 \\
# 3 & 4
# \end{bmatrix},
# \qquad
# B=
# \begin{bmatrix}
# 5 & 2 \\
# 1 & 6
# \end{bmatrix}
# $
#
# Compute the product.

# %%
a = [2,1,3,4]
b = [5,2,1,6]
A = np.array(a).reshape(2,2)
B = np.array(b).reshape(2,2)

# %%
A @ B
# Out:
# array([[11, 10],
#        [19, 30]])
