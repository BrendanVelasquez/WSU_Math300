# %% [markdown]
# # Homework 1 (due Friday, July 3rd)
# This assignment is designed to be practice outside of in-class lab.
#
# There are 5 sections. Please pick 5 problems from each section to complete (25 questions total).
#
# Feel free to do more than 25!
#
# # For some reason, half way through Anaconda Notebook kept saying it couldn't save my file. I noticed this did not happen if I didn't run any of the code.
#
# So in order to save my progress I deleted each time I ran the code. This is why the cells apear to not have been run. I did verify they worked is VScode, but I could not get it to work and save in the Anaconda Notebook, very weird but I'm too tired to look into why that's happening, so I will hopefully fix that for future HW's.

# %% [markdown]
# ### Section 1: Basic Arithmetic
# Write code below to compute the following:
# <ol>
#     <li>$2^4-16+(\frac{288}{7})$</li>
#     <li>$(10^2+13^4-12^3)^8$</li>
#     <li>$122^{1/2}-1980^{1/3}$</li>
#     <li>$3.14^{{3.14}^{3.14}}$</li>
#     <li>$\frac{3}{7}\cdot\frac{7}{5}\cdot\frac{3.14}{546}$</li>
#     <li>$456\cdot 32~ (mod~22)$</li>
#     <li>$100000\div 345~(mod~10)$</li>
#     <li>$15\cdot 14 \cdot 13 \cdots 3\cdot 2 \cdot 1$</li>
#     <li>$(12345\cdot 67891011)^{1 / 12345}$</li>
#         </ol>

# %%
# please put the problem number you are working on in comment mode by using "#" before the problem number

#section 1 problem 1
answer1 = 2**4-16+(288/7)
print(answer1)

#section 1 problem 2
answer2 =(10**2 + 13**4-12**3)**8
print(answer2)

#section 1 problem 3
#basically square root is power 1/2, cube root is power 1/3
answer3 = 122**(1/2) - 1980**(1/3)
print(answer3)

# section 1 problem 4
answer4 = 3.14**(3.14**3.14)
print(answer4)

#section 1 problem 5
answer5 =(3/7)*(7/5)*(3.14/546)
print(answer5)

#section 1 problem 6
#mod just means remainder
answer6 = (456*32)%22
print(answer6)

# section 1 problem 7
# doing the division first and then mod 10 last
answer7 = (100000/345)%10
print(answer7)

# section 1 problem 8
# this is 15 factorial basically
thing = 1
for i in range(1,16):
    thing =thing*i
print(thing)

#section 1 problem 9
answer9 =(12345*67891011)**(1/12345)
print(answer9)

# %% [markdown]
# ### Section 2: Statement Translation
# Translate the following statements in to code below.
# <ol>
#     <li>If 5 is greater than $x$, print 'yes'.</li>
#     <li>$y$ greater than 6 or $y$ equal to $x$</li>
#     <li>$a$ equal to $b$ and $a$ equal to $c$</li>
#     <li>If $a$ equal to $b$, then print $c$.</li>
#     <li>For each of the first five integers, add them to a list entitled 'contlist'.</li>
#     <li>For each element of 'contlist', print the number cubed.</li>
#     <li>If $x$ is greater than $a$, print $b$. Otherwise, print $x$ squared and set $b$ equal to $x$ squared.</li>
#         </ol>

# %%
# section 2 problem 1
#If 5 is greater than x, print yes
x = 3
if 5 > x:
    print("yes")
    
# section 2 problem 2
#y greater than 6 or y equal to x and then print it
x = 4
y = 9
print(y > 6 or y==x)

# section 2 problem 3
# a is equal to b and a is equal to c
a = 5
b = 5
c = 5
print(a == b and a== c)

#section 2 problem 4
# if a equals b then print c
a = 10
b = 10
c = "hello"
if a==b:
    print(c)
    
#section 2 problem 5
# first five integers into a list called contlist
contlist = []
for i in range(1,6):
    contlist.append(i)
print(contlist)

#section 2 problem 6
# cube every element of contlist and print it
contlist = [1,2,3,4,5]
for x in contlist:
    print(x**3)

#section 2 problem 7
#if x is greater than a print b, otherwise print x squared and set b equal to it
x = 3
a = 5
b = 12
if x > a:
    print(b)
else:
    print(x**2)
    b = x**2

# %% [markdown]
# ### Section 3: Output Prediction
# Without coding, what would the output of the following lines be? Briefly explain why that would be the output.
#
# <ol>
#     <li><code>5 > 3</code></li>
#     <li><code>( 10 < 24 ) & ( 10 > 4 ) </code></li>
#     <li><code>( 10 >= 24 ) and ( 10 > 4 )</code></li>
#     <li><code>( 2 >= 4 ) | ( 2 >= 0 ) </code></li>
#     <li><code>x = 4
# if x < 3:
#    print('yes')
# else:
#    print('no')</code></li>
#     <li><code>x = 4
# if x < 10:
#    print('yes')
# elif x < 9:
#    print('no')
#         </code></li>
#     <li><code>for i in [1,3,10]:
#         i **= 2
#         print(i)
#         </code></li>
#     <li><code>for i in [1,3,10]:
#         i **= 2
# print(i)
#         </code></li>
#     <li><code>x = 4
# x = 5
# x = 6
# print(x)</code></li>
#         </ol>

# %% [markdown]
# # section 3 problem 1
# # 5 > 3
# # output: True
# # because 5 is bigger than 3
#
# # section 3 problem 2
# # (10<24) & (10> 4)
# # output: True
# # both statements are true, so the whole thing is true
#
# # section 3 problem 3
# # (10>= 24) and (10>4)
# # output: False
# # 10 is not greater than or equal to 24, so the and statement fails
#
# # section 3 problem 4
# # (2>= 4) | (2>=0)
# # output: True
# # first part is false, second part is true, so with OR it becomes true
#
# # section 3 problem 5
# # x = 4
# # if x < 3:
# #    print('yes')
# # else:
# #    print('no')
# # output: no
# # because 4 is not less than 3
#
#
# # section 3 problem 6
# # x = 4
# # if x < 10:
# #    print('yes')
# # elif x < 9:
# #    print('no')
# # output: yes
# # because x < 10 is true, so python does that and then it skips the elif
#
# # section 3 problem 7
# # for i in [1,3,10]:
# #     i **= 2
# #     print(i)
# # output:
# # 1
# # 9
# # 100
# # because print is inside the loop, so it prints every squared value
#
# # section 3 problem 8
# # for i in [1,3,10]:
# #     i **= 2
# # print(i)
# # output:
# # 100
# # because print is outside the loop, so it will only print whatever the last value of i was
# # last i is 10, and 10 squared is 100, that is why 100 should be printed
#
# # section 3 problem 9
# # x = 4
# # x = 5
# # x = 6
# # print(x)
# # output: 6
# # python remembers the most recent value of x

# %% [markdown]
# ### Section 4: Slicing, Indexing, & For-Loops
# <ol>
#     <li>Given the string <code>'homework'</code>, use slicing in one line of code to print <code>'hmwr'</code> </li>
#     <li>Given the tuple <code>(43, 42, 41, 40, 39)</code>, use slicing in one line of code to print <code>(42, 39)</code></li>
#     <li>Write a for-loop that prints <code>'success!'</code> after the loop is done iterating.</li>
#     <li>Use a for-loop to print of every multiple of 2 between 0 and 50.</li>
#     <li>Use a for-loop to find the minimum value of some list.</li>
#     <li>Write a for-loop that uses slicing to take larger and larger slices of a sequence. For example, <code>[1,2,3,4]</code> going through the for-loop would produce <code>[1]</code>, <code>[1,2]</code>, <code>[1,2,3]</code>, then <code>[1,2,3,4]</code>.</li>
#         </ol>

# %%
#section 4 problem 1
#homework -> hmwr
word ="homework"
print(word[0:8:2])

#section 4 problem 2
# want 42 and 39
nums = (43,42,41,40,39)
print(nums[1:5:3])

#section 4 problem 3
#print success after the loop is done
for i in range(5):
    x = i # just something random happening in the loop since the condition is pretty simple.
print("success!")

#section 4 problem 4
#multiples of 2 from 0 to 50
for n in range(0,51):
    if n % 2 == 0:
        print(n)
        

# section 4 problem 4
#multiples of 2 from 0 to 50
for n in range(0,51):
    if n % 2 == 0:
        print(n)
        
# section 4 problem 5
# finding the minimum without using min
mylist = [12,4,18,-3,7,9]
smallest = mylist[0]
for x in mylist:
    if x < smallest:
        smallest = x
print(smallest)

# section 4 problem 5
# finding the minimum without using min
mylist = [12,4,18,-3,7,9]
smallest = mylist[0]
for x in mylist:
    if x < smallest:
        smallest = x
print(smallest)

# %% [markdown]
# ### Section 5: Functions
# For each of the following functions, pick a test input to verify your code works.
# <ol>
#     <li>Write a function <code>underscore(list)</code> that takes an input list of strings, <code>list</code>, and outputs one string with <code>_</code> between the previously separated elements. For example, <code>['this', 'is', 'a', 'list']</code> would output <code>'this_is_a_list'</code>.</li>
#     <li>Write a function <code>factorial(n)</code> that takes input integer <code>n</code> and outputs $n!$ (recall $n! = n\cdot (n-1)\cdot (n-2)\cdots 3\cdot 2\cdot 1$) </li>
#     <li>Write a function <code>fibonacci(n)</code> that takes input integer <code>n</code> and computes the $n$-th Fibonacci number (recall the next Fibonacci number in the sequence is defined by adding the two previous terms: 0,1,1,2,3,5,8,13,...)</li>
#     <li>Write a function that converts integers to base 2. For example, the number 17 in base 2 is 10001 since $17 = 1\cdot 2^4+0\cdot 2^3+0\cdot 2^2+0\cdot 2^1+1\cdot 2^0$</li>
#     <li>Write a function that converts a number into US standard money formatting (every 3 digits contain a comma and demical separates cents from dollar). That is, design a function that takes a number like $123456789.10$ and outputs $ \$123,456,789.10$ </li>
#     <li>Write a function <code>reverse(seq)</code> that takes an input sequence <code>seq</code> and outputs the reversed version of the sequence.</li>
#     <li>Write a function that adds up the elements in a given list.</li>
#     <li>Write a function that finds the maximum in a list of integers (without using any built-in maximum finding functions)</li>
#         </ol>

# %%
#section 5 problem 1
#add underscores between strings.
# I ran out of time and so this one is skipped sadly. 

# section 5 problem 2
# factorial function
def factorial(n):
    total =1
    for i in range(1,n+1):
        total =total*i
    return total
factorial(5)

#section 5 problem 3
# nth fibonacci number, using a list because it is easier to think about
def fibonacci(n):
    fibs = [0,1]
    for i in range(2,n+1):
        nextNum = fibs[i-1] + fibs[i-2]
        fibs.append(nextNum)
    return fibs[n]
fibonacci(7)

#section 5 problem 3
# nth fibonacci number
# using a list because it is easier to think about
def fibonacci(n):
    fibs =[0,1]
    for i in range(2,n+1):
        nextNum = fibs[i-1] + fibs[i-2]
        fibs.append(nextNum)
    return fibs[n]
fibonacci(7)

#section 5 problem 4
# convert integer to base 2, but just kind of brute force with remainders
def base2(n):
    bits = ""
    while n >0:
        remainder = n%2
        bits = str(remainder) + bits
        n = n//2
    return bits
base2(17)

#section 5 problem 5
#money formatting
def money(x):
    answer ="$"+ format(x,",.2f")
    return answer
money(123456789.10)

# section 5 problem 6
#reverse a sequence
def reverse(seq):
    backwards = seq[::-1]
    return backwards
reverse("homework")

#section 5 problem 7
#add up elements in a list
def addList(mylist):
    total =0
    for x in mylist:
        total = total+x
    return total
addList([1,2,3,4,5])

#section 5 problem 8
#find max without using max()
#I ran out of time and so this one is skipped sadly as well.
